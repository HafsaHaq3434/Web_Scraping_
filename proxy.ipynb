# %%
import requests

# %%
proxy_list = []
with open("D:\me.txt") as files:
    for fil in files:
        proxy_list.append(fil.strip())
print(len(proxy_list))
# Out:
# 300

# %%
runnig_ips=[]
for run in proxy_list:
  try:
    proxy={
        "http":"http://"+run,
        "https":"https://"+run
    }
    req=requests.get("https://httpbin.org/ip",proxies=proxy)
    runnig_ips.append(run)
  except:
    pass
len(runnig_ips)

# %%
import random
for i in range(len(runnig_ips)):
  random_ip=random.choice(runnig_ips)
  proxy={
        "http":"http://"+random_ip,
        "https":"http://"+random_ip
    }
  req=requests.get("https://httpbin.org/ip",proxies=proxy)

  print(req.text)

# %%
import requests
import random
from bs4 import BeautifulSoup as bs
import traceback


    # to store proxies

# %%
def get_free_proxies():
    url = "https://free-proxy-list.net/"
    # request and grab content
    soup = bs(requests.get(url).content, 'html.parser')
    proxies = []
    for row in soup.find("table", attrs={"class": "table-striped"}).find_all("tr")[1:]:
        tds = row.find_all("td")
        try:
            ip = tds[0].text.strip()
            port = tds[1].text.strip()
            proxies.append(str(ip) + ":" + str(port))
        except IndexError:
            continue
        
    return proxies
get_free_proxies()

# %%
url = "http://httpbin.org/ip"
proxies = get_free_proxies()

for i in range(len(proxies)):

    #printing req number
    print("Request Number : " + str(i+1))
    proxy = proxies[i]
    try:
        response = requests.get(url, proxies = {"http":proxy, "https":proxy})
        print(response.json())
    except:
        # if the proxy Ip is pre occupied
        print("Not Available")
# Out:
# Request Number : 1
# Not Available
# Request Number : 2
# Not Available
# Request Number : 3
# Not Available
# Request Number : 4
# {'origin': '43.255.113.232'}
# Request Number : 5
# Not Available
# Request Number : 6
# {'origin': '149.129.213.92'}
# Request Number : 7
# Not Available
# Request Number : 8
# Not Available
# Request Number : 9
# Not Available
# Request Number : 10
# {'origin': '80.66.81.40'}
# Request Number : 11
# Not Available
# Request Number : 12
# Not Available
# Request Number : 13
# Not Available
# Request Number : 14
# Not Available
# Request Number : 15
# {'origin': '78.38.28.239'}
# Request Number : 16
# Not Available
# Request Number : 17
# {'origin': '185.147.35.240'}
# Request Number : 18
# Not Available
# Request Number : 19
# {'origin': '198.59.191.249'}
# Request Number : 20
# {'origin': '42.3.19.148'}
# Request Number : 21
# {'origin': '169.57.1.85'}
# Request Number : 22
# {'origin': '51.15.242.202'}
# Request Number : 23
# ...
